# %% [markdown]
# ## 販売予測
# https://www.kaggle.com/c/rossmann-store-sales
# 3000店舗+7か国
# これから6週間の販売を予測したい
#
# 販促活動、競合、学校、国の祝日、季節、地域などに影響されている
# 個別の予測をやっていますが、精度は異なっています。
#
# 未来の6週間のドイツの1115店舗の売上を予測する必要があります。
# 何に影響されやすいかも考えましょう

# %% [markdown]
# ### データインポート、観察

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
st = pd.read_csv('./data_ross/store.csv')
train_df = pd.read_csv('./data_ross/train.csv')
test_df = pd.read_csv('./data_ross/test.csv')

# %%
st.head(5)
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
train_df.head(5)
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
# Store                        1115 non-null int64
# StoreType                    1115 non-null object
# Assortment                   1115 non-null object
# CompetitionDistance          1112 non-null float64
# CompetitionOpenSinceMonth    761 non-null float64
# CompetitionOpenSinceYear     761 non-null float64
# Promo2                       1115 non-null int64
# Promo2SinceWeek              571 non-null float64
# Promo2SinceYear              571 non-null float64
# PromoInterval                571 non-null object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
# Store            1017209 non-null int64
# DayOfWeek        1017209 non-null int64
# Date             1017209 non-null object
# Sales            1017209 non-null int64
# Customers        1017209 non-null int64
# Open             1017209 non-null int64
# Promo            1017209 non-null int64
# StateHoliday     1017209 non-null object
# SchoolHoliday    1017209 non-null int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %% [markdown]
# ### 前処理
# 欠損値と異常値の確認、処理

# %%
train_df.isnull().any()
# Out:
# Store            False
# DayOfWeek        False
# Date             False
# Sales            False
# Customers        False
# Open             False
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %%
st.isnull().any()
# Out:
# Store                        False
# StoreType                    False
# Assortment                   False
# CompetitionDistance           True
# CompetitionOpenSinceMonth     True
# CompetitionOpenSinceYear      True
# Promo2                       False
# Promo2SinceWeek               True
# Promo2SinceYear               True
# PromoInterval                 True
# dtype: bool

# %% [markdown]
# #### 欠損値処理

# %%
st[st['CompetitionDistance'].isnull()]
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 290    291         d          a                  NaN
# 621    622         a          c                  NaN
# 878    879         d          a                  NaN
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 290                        NaN                       NaN       0
# 621                        NaN                       NaN       0
# 878                        NaN                       NaN       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 290              NaN              NaN              NaN
# 621              NaN              NaN              NaN
# 878              5.0           2013.0  Feb,May,Aug,Nov

# %% [markdown]
# CompetitionDistanceに関して、
# そもそも競合がなければ、nullになるのも可能です。

# %%
st[st['CompetitionOpenSinceMonth'].isnull()].head(5)
# Out:
#     Store StoreType Assortment  CompetitionDistance  \
# 11     12         a          c               1070.0
# 12     13         d          a                310.0
# 15     16         a          c               3270.0
# 18     19         a          c               3240.0
# 21     22         a          a               1040.0
#
#     CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 11                        NaN                       NaN       1
# 12                        NaN                       NaN       1
# 15                        NaN                       NaN       0
# 18                        NaN                       NaN       1
# 21                        NaN                       NaN       1
#
#     Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 11             13.0           2010.0   Jan,Apr,Jul,Oct
# 12             45.0           2009.0   Feb,May,Aug,Nov
# 15              NaN              NaN               NaN
# ...

# %%
st[st['CompetitionOpenSinceYear'].isnull()].head(5)
# Out:
#     Store StoreType Assortment  CompetitionDistance  \
# 11     12         a          c               1070.0
# 12     13         d          a                310.0
# 15     16         a          c               3270.0
# 18     19         a          c               3240.0
# 21     22         a          a               1040.0
#
#     CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 11                        NaN                       NaN       1
# 12                        NaN                       NaN       1
# 15                        NaN                       NaN       0
# 18                        NaN                       NaN       1
# 21                        NaN                       NaN       1
#
#     Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 11             13.0           2010.0   Jan,Apr,Jul,Oct
# 12             45.0           2009.0   Feb,May,Aug,Nov
# 15              NaN              NaN               NaN
# ...

# %% [markdown]
# CompetitionOpenSinceMonth、CompetitionOpenSinceYearに関して、
# わからない場合もあり、nullになるのも許される。
# CompetitionDistance、
# CompetitionOpenSinceMonth、
# CompetitionOpenSinceYearに関して、
# 平均で補完します

# %%
print(st[st['Promo2SinceWeek'].isnull()].shape)
print(st[st['Promo2SinceYear'].isnull()].shape)
print(st[st['PromoInterval'].isnull()].shape)
# Out:
# (544, 10)
# (544, 10)
# (544, 10)

# %% [markdown]
# 販促をやらない場合、販促活動のデータもないのも当然です。
# ただし、このままでは処理できないため、
# 0で補完

# %%
cols1 = ['CompetitionDistance','CompetitionOpenSinceMonth','CompetitionOpenSinceYear']
st[cols1] = st[cols1].fillna(st[cols1].mean()).astype(int)

cols2 = ['Promo2SinceWeek','Promo2SinceYear']

st[cols2] = st[cols2].fillna(0)

st['PromoInterval'] = st['PromoInterval'].fillna('NoPromo')

# %%
st.isnull().any()
# Out:
# Store                        False
# StoreType                    False
# Assortment                   False
# CompetitionDistance          False
# CompetitionOpenSinceMonth    False
# CompetitionOpenSinceYear     False
# Promo2                       False
# Promo2SinceWeek              False
# Promo2SinceYear              False
# PromoInterval                False
# dtype: bool

# %% [markdown]
# #### 異常値
# st と train_df

# %% [markdown]
# __train__

# %%
train_df.describe().round(2)
# Out:
#             Store  DayOfWeek       Sales   Customers        Open       Promo  \
# count  1017209.00  1017209.0  1017209.00  1017209.00  1017209.00  1017209.00
# mean       558.43        4.0     5773.82      633.15        0.83        0.38
# std        321.91        2.0     3849.93      464.41        0.38        0.49
# min          1.00        1.0        0.00        0.00        0.00        0.00
# 25%        280.00        2.0     3727.00      405.00        1.00        0.00
# 50%        558.00        4.0     5744.00      609.00        1.00        0.00
# 75%        838.00        6.0     7856.00      837.00        1.00        1.00
# max       1115.00        7.0    41551.00     7388.00        1.00        1.00
#
#        SchoolHoliday
# count     1017209.00
# mean            0.18
# std             0.38
# min             0.00
# 25%             0.00
# 50%             0.00
# 75%             0.00
# max             1.00

# %% [markdown]
# sales、Customers(番号❓)、に大きい数値があります。
# それ以外はオッケー

# %%
sns.boxplot(train_df['Sales'])

# %%
train_df.sort_values('Sales',ascending=False).head(5)
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 44393     909          1  2015-06-22  41551       1721     1      0
# 132946    262          5  2015-04-03  38722       5132     1      1
# 101726    262          5  2015-05-01  38484       5458     1      1
# 87231     262          4  2015-05-14  38367       5192     1      0
# 424086     57          1  2014-06-16  38037       1970     1      1
#
#        StateHoliday  SchoolHoliday
# 44393             0              0
# 132946            b              0
# 101726            a              0
# 87231             a              1
# 424086            0              0

# %% [markdown]
# とてつもなく不可能な数値ではないため、除去しません

# %%
sns.boxplot(train_df['Customers'])

# %%
train_df.sort_values('Customers',ascending=False).head(5)
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 993496    817          2  2013-01-22  27190       7388     1      1
# 319810    262          5  2014-10-03  35702       5494     1      1
# 101726    262          5  2015-05-01  38484       5458     1      1
# 432096    262          1  2014-06-09  34692       5387     1      0
# 444361    262          4  2014-05-29  37403       5297     1      0
#
#        StateHoliday  SchoolHoliday
# 993496            0              0
# 319810            a              0
# 101726            a              0
# 432096            a              0
# 444361            a              0

# %% [markdown]
# とてつもなく不可能な数値ではないため、除去しません

# %% [markdown]
# __store__

# %%
st.describe().round(2)
# Out:
#          Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00              1115.00                    1115.00
# mean    558.00              5404.90                       7.15
# std     322.02              7652.85                       2.66
# min       1.00                20.00                       1.00
# 25%     279.50               720.00                       6.00
# 50%     558.00              2330.00                       7.00
# 75%     836.50              6875.00                       9.00
# max    1115.00             75860.00                      12.00
#
#        CompetitionOpenSinceYear   Promo2  Promo2SinceWeek  Promo2SinceYear
# count                   1115.00  1115.00          1115.00          1115.00
# mean                    2008.46     0.51            12.08          1030.24
# std                        5.13     0.50            15.54          1006.04
# min                     1900.00     0.00             0.00             0.00
# ...

# %% [markdown]
# rossmannは1972年創業、
# CompetitionOpenSinceYearが1900年になっているものをチェックする必要があります
# 競合との距離に、非常に大きい数値がります。

# %%
st.sort_values('CompetitionOpenSinceYear').head(5)
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 814    815         a          a                  590
# 145    146         d          c                 8050
# 540    541         a          c                  650
# 328    329         a          a                 1310
# 991    992         a          a                 2480
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 814                          1                      1900       1
# 145                         10                      1961       1
# 540                          7                      1990       0
# 328                          6                      1990       1
# 991                          7                      1990       0
#
#      Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 814             40.0           2014.0   Jan,Apr,Jul,Oct
# 145             48.0           2012.0   Jan,Apr,Jul,Oct
# 540              0.0              0.0           NoPromo
# ...

# %% [markdown]
# 老舗だと考えても、不可はない
# 保留

# %% [markdown]
# これで欠損値異常値は除去済み

# %% [markdown]
# 最後は、dateの型を転換

# %%
train_df['Date'] = train_df['Date'].astype('datetime64')

# %% [markdown]
# ### 基礎集計

# %% [markdown]
# 店舗を観察

# %%
st.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a                 1270                          9
# 1      2         a          a                  570                         11
# 2      3         a          a                14130                         12
# 3      4         c          c                  620                          9
# 4      5         a          a                29910                          4
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                      2008       0              0.0              0.0
# 1                      2007       1             13.0           2010.0
# 2                      2006       1             14.0           2011.0
# 3                      2009       0              0.0              0.0
# 4                      2015       0              0.0              0.0
#
#      PromoInterval
# 0          NoPromo
# 1  Jan,Apr,Jul,Oct
# ...

# %%
bar1 = st.groupby('StoreType').count()
display(bar1['Store'])
plt.bar(left=bar1.index,height=bar1['Store'])
# Out:
# StoreType
# a    602
# b     17
# c    148
# d    348
# Name: Store, dtype: int64
# <BarContainer object of 4 artists>

# %% [markdown]
# Aが一番多い

# %%
bar2 = st.groupby('Assortment').count()
display(bar2['Store'])
plt.bar(left=bar2.index,height=bar2['Store']);
# Out:
# Assortment
# a    593
# b      9
# c    513
# Name: Store, dtype: int64

# %% [markdown]
# aとcが多い、bはわずか

# %%
st.groupby(['StoreType','Assortment']).count()['Store']
# Out:
# StoreType  Assortment
# a          a             381
#            c             221
# b          a               7
#            b               9
#            c               1
# c          a              77
#            c              71
# d          a             128
#            c             220
# Name: Store, dtype: int64

# %%
st.groupby('Promo2').count()['Store']
# Out:
# Promo2
# 0    544
# 1    571
# Name: Store, dtype: int64

# %% [markdown]
# 連続販促に参加する店舗としない店舗の数は大差ない

# %%
st.groupby('PromoInterval').count()['Store']
# Out:
# PromoInterval
# Feb,May,Aug,Nov     130
# Jan,Apr,Jul,Oct     335
# Mar,Jun,Sept,Dec    106
# NoPromo             544
# Name: Store, dtype: int64

# %% [markdown]
# 参加の場合、基本的に3か月に1回参加する。パターンは3パターンあります。

# %% [markdown]
# マスターデータの単独集計は以上

# %% [markdown]
# train を単体集計

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
train_df.groupby('StateHoliday').count()
# Out:
#                Store  DayOfWeek    Date   Sales  Customers    Open   Promo  \
# StateHoliday
# 0             131072     131072  131072  131072     131072  131072  131072
# 0             855087     855087  855087  855087     855087  855087  855087
# a              20260      20260   20260   20260      20260   20260   20260
# b               6690       6690    6690    6690       6690    6690    6690
# c               4100       4100    4100    4100       4100    4100    4100
#
#               SchoolHoliday
# StateHoliday
# 0                    131072
# 0                    855087
# a                     20260
# b                      6690
# c                      4100

# %% [markdown]
# 0=0 a=1 b=2 c=3 に置き換えましょう。

# %%
train_df['StateHoliday'] = train_df['StateHoliday'].replace({'a':1,'b':2,'c':3}).astype(int)

# %% [markdown]
# SchoolHoliday観察

# %%
date_holiday = train_df[['Date','StateHoliday','SchoolHoliday','Open']]
date_holiday.groupby([pd.Grouper(key='Date',freq='30d'),'StateHoliday']).count()
# Out:
#                          SchoolHoliday   Open
# Date       StateHoliday
# 2013-01-01 0                     32026  32026
#            1                      1423   1423
# 2013-01-31 0                     33450  33450
# 2013-03-02 0                     32335  32335
#            2                      1115   1115
# 2013-04-01 0                     32335  32335
#            2                      1115   1115
# 2013-05-01 0                     29339  29339
#            1                      4111   4111
# 2013-05-31 0                     33450  33450
# 2013-06-30 0                     33450  33450
# 2013-07-30 0                     33270  33270
#            1                       180    180
# 2013-08-29 0                     33450  33450
# 2013-09-28 0                     32335  32335
#            1                      1115   1115
# 2013-10-28 0                     32629  32629
#            1                       821    821
# 2013-11-27 0                     31220  31220
# ...

# %% [markdown]
# 結合して観察

# %%
df = train_df.join(st,on='Store',how='left', lsuffix='_left', rsuffix='_right')
df.head(5)
# Out:
#    Store_left  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0           1          5 2015-07-31   5263        555     1      1
# 1           2          5 2015-07-31   6064        625     1      1
# 2           3          5 2015-07-31   8314        821     1      1
# 3           4          5 2015-07-31  13995       1498     1      1
# 4           5          5 2015-07-31   4822        559     1      1
#
#    StateHoliday  SchoolHoliday  Store_right StoreType Assortment  \
# 0             0              1          2.0         a          a
# 1             0              1          3.0         a          a
# 2             0              1          4.0         c          c
# 3             0              1          5.0         a          a
# 4             0              1          6.0         a          a
#
#    CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0                570.0                       11.0                    2007.0
# ...

# %%
df.loc[df['Store_right'].isnull(),'Store_left'].drop_duplicates()
# Out:
# 1114    1115
# Name: Store_left, dtype: int64

# %% [markdown]
# この2店舗のデータがない、削除しても大丈夫そうなので削除します。

# %%
df=df.dropna()

# %% [markdown]
# 時系列的な観察

# %%
def plot_ts(feature,freq):
    date_sales = df.groupby([pd.Grouper(key='Date',freq=freq)]).sum().reset_index()# count()
    date_sales = date_sales.loc[~(date_sales[feature]==0),['Date',feature]]
    #店が閉まる日も除去
    plt.figure(figsize=(15,5))
    plt.plot(date_sales['Date'],date_sales[feature])

# %%
plot_ts('Customers','7d')

# %%
#月別
plot_ts('Sales','1m')

# %%
plot_ts('Customers','1m')

# %% [markdown]
# 基本的に顧客数と売上の増減は一致
# でも意味がないです。
# そもそもテストデータにcustomersってないです

# %% [markdown]
# feature別売上合計

# %%
def plot_feature_sales(feature):
    data = df.groupby(feature).sum().reset_index()
    data = data.loc[~(data['Sales']==0),[feature,'Sales']]
    return data[feature],data['Sales']

# %%
plot_feature_sales('PromoInterval')
# Out:
# (0     Feb,May,Aug,Nov
#  1     Jan,Apr,Jul,Oct
#  2    Mar,Jun,Sept,Dec
#  3             NoPromo
#  Name: PromoInterval, dtype: object, 0     706248203
#  1    1771988481
#  2     576813872
#  3    2813207838
#  Name: Sales, dtype: int64)

# %%
df.columns
# Out:
# Index(['Store_left', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open',
#        'Promo', 'StateHoliday', 'SchoolHoliday', 'Store_right', 'StoreType',
#        'Assortment', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval'],
#       dtype='object')

# %%
categorical_features = ['DayOfWeek', 'Open',
       'Promo', 'StateHoliday', 'SchoolHoliday', 'Store_right', 'StoreType',
       'Assortment',
       'Promo2','PromoInterval']

fig = plt.figure(figsize=(20,20));
for i,f in enumerate(categorical_features):
    ax=plt.subplot(4,4,i+1);
    left,height = plot_feature_sales(f)
    ax.bar(left=left,height=height);
    ax.set_xlabel(f);

# %%
numeric_features = ['CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2SinceWeek',
       'Promo2SinceYear']

# %%
fig = plt.figure(figsize=(20,20));
for i,f in enumerate(numeric_features):
    ax=plt.subplot(4,4,i+1);
    ax.scatter(df[f],df['Sales']);
    ax.set_xlabel(f);

# %% [markdown]
# 店舗によるところもありますが、
# 直接な強い相関関係はなさそうです。
# 競合との距離が離れると、売上も減る。
# これは、競合との距離が離れ、つまり繁華街でないところ、つまりカスタマが少ない、売上も少ないというロジックで考えてよいと思います。

# %% [markdown]
# ### ここまでの反省
# store欠損値除去の後、 (train×store)結合テーブルも一回異常値除去したほうがいいかもしれないです。
#
# 統一countや、sumなどの集計をやるんだったら、関数化して、
# 1つのセルに複数のグラフを作ったほうがいいかもしれない

# %%
df.groupby(['Store_right','Promo']).count()
# Out:
#                    Store_left  DayOfWeek  Date  Sales  Customers  Open  \
# Store_right Promo
# 2.0         0             582        582   582    582        582   582
#             1             360        360   360    360        360   360
# 3.0         0             582        582   582    582        582   582
#             1             360        360   360    360        360   360
# 4.0         0             582        582   582    582        582   582
#             1             360        360   360    360        360   360
# 5.0         0             582        582   582    582        582   582
#             1             360        360   360    360        360   360
# 6.0         0             582        582   582    582        582   582
#             1             360        360   360    360        360   360
# 7.0         0             582        582   582    582        582   582
#             1             360        360   360    360        360   360
# ...

# %% [markdown]
# ### 特徴量作成

# %% [markdown]
# これ以外関係しそうなものはありますか。?
#
# 1、競合が今までどれぐらい時間を経っているのか
# 2、ある時点で競合は出店しているかどうか
# 3、販促活動はどれぐらい長くやったのか
# 4、店舗の今までの売上平均、
# 5、人数平均、
# 6、店舗の最近1ヵ月の人数平均、
# 7、最近3か月の人数平均、
# 8、最近1年の人数平均
#
# 9、店舗別holiday、promotionに影響される指数
# 　holidayの売上合計/平日売上合計
# 　promotionの売上合計/平日売上合計
# 10、

# %%
#1、競合が今までどれぐらい時間を経っているのか
import datetime
# opendate = df.apply(lambda x: datetime.datetime(x['CompetitionOpenSinceYear'],x['CompetitionOpenSinceMonth']))
# df['CompetitionOpenDate'] = datetime.datetime(df['CompetitionOpenSinceYear'],df['CompetitionOpenSinceMonth'])
#  
df['CompetitionLife'] = 2019 - df['CompetitionOpenSinceYear']

# %%
#2ある時点で競合は出店しているかどうか
m = df['Date'].dt.month
d = df['Date'].dt.year

df.iloc[,'Have_Competition'] =1

df.iloc[,'Have_Competition'] =0
# Out:
#   File "<ipython-input-67-ee4f95b02b33>", line 5
#     df.iloc[,'Have_Competition'] =1
#             ^
# SyntaxError: invalid syntax

# %%
#販促活動はどれぐらい長くやったのか
df[]
# Out:
#          Store_left  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0                 1          5 2015-07-31   5263        555     1      1
# 1                 2          5 2015-07-31   6064        625     1      1
# 2                 3          5 2015-07-31   8314        821     1      1
# 3                 4          5 2015-07-31  13995       1498     1      1
# 4                 5          5 2015-07-31   4822        559     1      1
# 5                 6          5 2015-07-31   5651        589     1      1
# 6                 7          5 2015-07-31  15344       1414     1      1
# 7                 8          5 2015-07-31   8492        833     1      1
# 8                 9          5 2015-07-31   8565        687     1      1
# 9                10          5 2015-07-31   7185        681     1      1
# 10               11          5 2015-07-31  10457       1236     1      1
# 11               12          5 2015-07-31   8959        962     1      1
# ...

# %%
store_mean= df.groupby('Store_left').mean().reset_index()[['Store_left','Sales']]
store_mean=store_mean.rename(columns={
    'Sales':'SalesMean'
})
store_mean.head()
# Out:
#       Store_left     SalesMean
# 0              1   3945.704883
# 1              2   4122.991507
# 2              3   5741.253715
# 3              4   8021.769639
# 4              5   3867.110403
# 5              6   4562.375796
# 6              7   7356.902335
# 7              8   4610.251592
# 8              9   5426.816348
# 9             10   4634.439490
# 10            11   6683.955414
# 11            12   6316.608280
# 12            13   4124.773087
# 13            14   4555.386412
# 14            15   5553.619958
# 15            16   6335.340764
# 16            17   5259.541401
# 17            18   5446.005308
# 18            19   5346.251592
# 19            20   6334.489446
# 20            21   4522.041401
# 21            22   3695.918206
# 22            23   4565.073248
# 23            24   7763.773885
# 24            25   8892.311040
# 25            26   5538.498938
# 26            27   7838.438429
# 27            28   4332.218684
# 28            29   6090.403397
# ...

# %% [markdown]
# ### モデリング

# %%
#ロジステック回帰
from sklearn.linear_model import LogisticRegression
#決定木
from sklearn.tree import DecisionTreeClassifier
#SVM
from sklearn.svm import SVC
#SVM
from sklearn.ensemble import RandomForestClassifier
#LGB
import lightgbm as lgb
#XGB
import xgboost as xgb
#ADAB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
import time

model_list = [
    'LogisticRegression', 'DecisionTreeClassifier' ,'RandomForestClassifier','lgb.LGBMClassifier'
    ,'xgb.XGBClassifier'
]
accuracy = []
times = []
for model in model_list:
        start = time.time()
        
        md = eval(model + '()')
        md.fit(X_train, y_train)
        y_pred = md.predict(X_val)
        print(str(model), ' : ', accuracy_score(y_val,y_pred))
        
        end = time.time()
        t=end-start
        times.append(t)
        accuracy.append(accuracy_score(y_val,y_pred))

# %%
plt.figure(figsize=(10,4))
X1 = [i for i in range(len(model_list))]
Y1 = accuracy

X2 = [i+0.4 for i in range(len(model_list))]
Y2 = times

plt.bar(X1, Y1,  width=0.4, label='正解率　', align="center")
plt.legend(bbox_to_anchor=(1.15, 1.2), loc='upper left')
plt.ylabel('正解率')
plt.twinx()
plt.bar(X2, Y2, color='g', width=0.4, label='処理時間', align="center")
plt.legend(bbox_to_anchor=(1.15, 1), loc='upper left')
plt.ylabel('処理時間')

# X軸の目盛りを書き換える
plt.xticks([i+0.2 for i in range(len(model_list))],  [
    'Logistic\nRegression', 'Decision\nTree','Random\nForest','LightGBM','XGBoost'
])
plt.title('モデル比較')

# %% [markdown]
# ### チューニング

# %%
from sklearn.model_selection import GridSearchCV
# 優れたハイパーパラメータを見つけたいモデル
estimator = lgb.LGBMClassifier()

param_grid = {
    'num_leaves':[44,45,46],
    'learning_rate':[0.16,0.17,0.18,0.19],
    'n_estimators': [37,38,39],
    'max_depth': [5,10,20],
#     'min_child_samples': [18, 20, 22],
#     'min_child_weight':[0.001, 0.002],
#     'feature_fraction': [0.5, 0.7, 0.9],
#     'bagging_fraction': [0.6, 0.8,1.0]
}


#

gbm = GridSearchCV(estimator, param_grid, cv=3)
gbm.fit(X_train, y_train)

print(gbm.best_score_)  # 最も良かったスコア
print(gbm.best_params_)  # 上記を記録したパラメータの組み合わせ
