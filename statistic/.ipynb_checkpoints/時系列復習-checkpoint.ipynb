# %% [markdown]
# ### 時系列 理論

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as SNS 

from scipy import stats
import statsmodels.api as sm

# %% [markdown]
# https://logics-of-blue.com/python-time-series-analysis/

# %%
# df = pd.read_csv('./data_time_series/AirPassengers.csv').set_index('Month')
data = pd.read_csv('./data_time_series/AirPassengers.csv', 
                   index_col='Month', 
                   parse_dates=True, 
                   dtype='float')
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01        112.0
# 1949-02-01        118.0
# 1949-03-01        132.0
# 1949-04-01        129.0
# 1949-05-01        121.0

# %%
df.head()
# Out:
#          #Passengers
# Month
# 1949-01          112
# 1949-02          118
# 1949-03          132
# 1949-04          129
# 1949-05          121

# %%
ts = data['#Passengers']

# %%
plt.plot(ts)

# %% [markdown]
# ・乗客数が年々増えているということ。
# ・季節ごとに乗客数が周期的に変わりそうだということ。

# %%
diff = ts - ts.shift()

# %%
logDiff = np.log(ts) - np.log(ts.shift())

# %%
plt.plot(diff)

# %%
plt.plot(logDiff)

# %% [markdown]
# 自己関数、係数推定

# %%
ts_acf = sm.tsa.stattools.acf(ts,nlags=40)
ts_acf
# Out:
# array([1.        , 0.94804734, 0.87557484, 0.80668116, 0.75262542,
#        0.71376997, 0.6817336 , 0.66290439, 0.65561048, 0.67094833,
#        0.70271992, 0.74324019, 0.76039504, 0.71266087, 0.64634228,
#        0.58592342, 0.53795519, 0.49974753, 0.46873401, 0.44987066,
#        0.4416288 , 0.45722376, 0.48248203, 0.51712699, 0.53218983,
#        0.49397569, 0.43772134, 0.3876029 , 0.34802503, 0.31498388,
#        0.28849682, 0.27080187, 0.26429011, 0.27679934, 0.2985215 ,
#        0.32558712, 0.3370236 , 0.30333486, 0.25397708, 0.21065534,
#        0.17217092])

# %% [markdown]
# 偏自己相関

# %%
ts_pacf = sm.tsa.stattools.pacf(ts, nlags=40, method='ols')
ts_pacf
# Out:
# array([ 1.        ,  0.95893198, -0.32983096,  0.2018249 ,  0.14500798,
#         0.25848232, -0.02690283,  0.20433019,  0.15607896,  0.56860841,
#         0.29256358,  0.8402143 ,  0.61268285, -0.66597616, -0.38463943,
#         0.0787466 , -0.02663483, -0.05805221, -0.04350748,  0.27732556,
#        -0.04046447,  0.13739883,  0.3859958 ,  0.24203808, -0.04912986,
#        -0.19599778, -0.15443575,  0.04484465,  0.18371541, -0.0906113 ,
#        -0.06202938,  0.34827092,  0.09899499, -0.08396793,  0.36328898,
#        -0.17956662,  0.15839435,  0.06376775, -0.27503705,  0.2707607 ,
#         0.32002003])

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(2,1,1)
fig = sm.graphics.tsa.plot_acf(ts,lags = 30,ax = ax1)
ax2 = fig.add_subplot(2,1,2)
fig = sm.graphics.tsa.plot_pacf(ts, lags=30, ax=ax2)

# %% [markdown]
# 1か月後と12か月後が著しい
# 1、前月が多ければ今月も多い
# 2、去年のこの月が多ければ、来年も多い

# %%
diff = ts - ts.shift()
diff = diff.dropna()

# %%
resDiff = sm.tsa.arma_order_select_ic(diff , ic = 'aic',trend = 'nc')
resDiff
# Out:
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# {'aic':              0            1            2
#  0          NaN  1397.257791  1397.093436
#  1  1401.852641  1412.615224  1385.496795
#  2  1396.587654  1378.338024  1353.175734
#  3  1395.021214  1379.614000  1351.138710
#  4  1388.216680  1379.616584  1373.560615, 'aic_min_order': (3, 2)}

# %%
from statsmodels.tsa.arima_model import ARIMA

ARIMA_3_1_2 = ARIMA(ts,order = (3,1,2)).fit(dist = False)
ARIMA_3_1_2.params
# Out:
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# const                  2.673504
# ar.L1.D.#Passengers    0.261991
# ar.L2.D.#Passengers    0.367830
# ar.L3.D.#Passengers   -0.363472
# ma.L1.D.#Passengers   -0.075064
# ma.L2.D.#Passengers   -0.924862
# dtype: float64

# %%
resid = ARIMA_3_1_2.resid
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid.values.squeeze(), lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid, lags=40, ax=ax2)

# %%
import statsmodels.api as sm

SARIMA_3_1_2_111 = sm.tsa.SARIMAX(ts, order=(3,1,2), seasonal_order=(1,1,1,12)).fit()
print(SARIMA_3_1_2_111.summary())
# Out:
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                        #Passengers   No. Observations:                  144
# Model:             SARIMAX(3, 1, 2)x(1, 1, 1, 12)   Log Likelihood                -502.967
# Date:                            Tue, 11 Dec 2018   AIC                           1021.934
# Time:                                    15:20:33   BIC                           1044.935
# Sample:                                01-01-1949   HQIC                          1031.280
#                                      - 12-01-1960
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6707      1.520      0.441      0.659      -2.308       3.649
# ar.L2          0.2093      0.902      0.232      0.816      -1.558       1.977
# ar.L3         -0.0716      0.355     -0.202      0.840      -0.767       0.623
# ma.L1         -1.0564      1.546     -0.683      0.494      -4.087       1.974
# ma.L2          0.0794      1.513      0.052      0.958      -2.887       3.046
# ar.S.L12      -0.8642      0.288     -2.999      0.003      -1.429      -0.299
# ma.S.L12       0.7645      0.372      2.054      0.040       0.035       1.494
# sigma2       124.8744     14.371      8.689      0.000      96.708     153.041
# ===================================================================================
# Ljung-Box (Q):                       50.96   Jarque-Bera (JB):                14.12
# Prob(Q):                              0.11   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.60   Skew:                             0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\ko_kaku\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
