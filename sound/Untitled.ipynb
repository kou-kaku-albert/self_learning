# %%
# !pip install audioread

# %%
# !pip install librosa

# %%
import librosa
import matplotlib.pyplot as plt

# %%
librosa.__version__
# Out:
# '0.6.3'

# %%
y, sr = librosa.load('ex0.wav')

# %%
y
# Out:
# array([-0.73689854, -1.0800318 , -0.9519966 , ..., -1.0097102 ,
#        -0.9775502 , -1.0539925 ], dtype=float32)

# %%
sr
# Out:
# 22050

# %%
# Out:
# 986731

# %%
tempo,beat_frames =librosa.beat.beat_track(y=y ,sr=sr)

# %%
print('Estimated tempo: {:.2f} beats per minute'.format(tempo))
# Out:
# Estimated tempo: 80.75 beats per minute

# %%
beat_times = librosa.frames_to_time(beat_frames, sr=sr)

# %%
beat_frames
# Out:
# array([  44,   87,  119,  152,  184,  216,  249,  281,  314,  346,  378,
#         410,  443,  475,  507,  539,  572,  604,  637,  669,  701,  733,
#         766,  798,  831,  868,  905,  938,  970, 1003, 1035, 1067, 1100,
#        1132, 1164, 1193, 1222, 1250, 1282, 1315, 1347, 1379, 1412, 1444,
#        1476, 1508, 1541, 1573, 1605, 1638, 1670, 1702, 1735, 1767, 1799,
#        1831, 1862, 1893])

# %%
plt.plot(y)

# %%
y_harmonic, y_percussive = librosa.effects.hpss(y)

# %%
y_harmonic
plt.plot(y_harmonic)

# %%
y_percussive
plt.plot(y_percussive)
